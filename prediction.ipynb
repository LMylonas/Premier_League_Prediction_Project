# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %% [markdown]
# ### Importing & cleaning data

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# 1         West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1.0
# 2      Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0  0.0
# 3    Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0  0.0
# 4   Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0  0.0
# 5  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0  0.0
#
#   pkatt  season             team
# 1   1.0    2023  Manchester City
# 2   0.0    2023  Manchester City
# 3   0.0    2023  Manchester City
# 4   0.0    2023  Manchester City
# 5   0.0    2023  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1520, 27)

# %%
matches['date'] = pd.to_datetime(matches['date'])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %% [markdown]
# ### Creating predictors for machine learning:

# %%
matches['venue_code'] = matches['venue'].astype('category').cat.codes

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# 1         West Ham  ...    NaN  13.0   1.0  18.7  1.0  1.0   1.0   2023
# 2      Bournemouth  ...    NaN  19.0   7.0  17.5  0.0  0.0   0.0   2023
# 3    Newcastle Utd  ...    NaN  21.0  10.0  16.2  1.0  0.0   0.0   2023
# 4   Crystal Palace  ...    NaN  18.0   5.0  14.1  0.0  0.0   0.0   2023
# 5  Nott'ham Forest  ...    NaN  17.0   9.0  14.8  0.0  0.0   0.0   2023
#
#               team  venue_code
# 1  Manchester City           0
# 2  Manchester City           1
# 3  Manchester City           0
# 4  Manchester City           1
# 5  Manchester City           1
#
# [5 rows x 28 columns]

# %%
matches['opp_code'] = matches['opponent'].astype('category').cat.codes

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# 1         West Ham  ...  13.0   1.0  18.7  1.0  1.0   1.0   2023
# 2      Bournemouth  ...  19.0   7.0  17.5  0.0  0.0   0.0   2023
# 3    Newcastle Utd  ...  21.0  10.0  16.2  1.0  0.0   0.0   2023
# 4   Crystal Palace  ...  18.0   5.0  14.1  0.0  0.0   0.0   2023
# 5  Nott'ham Forest  ...  17.0   9.0  14.8  0.0  0.0   0.0   2023
#
#               team  venue_code  opp_code
# 1  Manchester City           0        21
# 2  Manchester City           1         2
# 3  Manchester City           0        15
# 4  Manchester City           1         7
# 5  Manchester City           1        17
#
# [5 rows x 29 columns]

# %%
matches['hour'] = matches['time'].str.replace(":.+", '', regex=True).astype('int')

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...   sot  dist   fk   pk pkatt season             team  \
# 1         West Ham  ...   1.0  18.7  1.0  1.0   1.0   2023  Manchester City
# 2      Bournemouth  ...   7.0  17.5  0.0  0.0   0.0   2023  Manchester City
# 3    Newcastle Utd  ...  10.0  16.2  1.0  0.0   0.0   2023  Manchester City
# 4   Crystal Palace  ...   5.0  14.1  0.0  0.0   0.0   2023  Manchester City
# 5  Nott'ham Forest  ...   9.0  14.8  0.0  0.0   0.0   2023  Manchester City
#
#   venue_code  opp_code  hour
# 1          0        21    16
# 2          1         2    15
# 3          0        15    16
# 4          1         7    15
# 5          1        17    19
#
# [5 rows x 30 columns]

# %%
matches['day_code'] = matches['date'].dt.dayofweek

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...  dist   fk   pk  pkatt season             team  \
# 1         West Ham  ...  18.7  1.0  1.0    1.0   2023  Manchester City
# 2      Bournemouth  ...  17.5  0.0  0.0    0.0   2023  Manchester City
# 3    Newcastle Utd  ...  16.2  1.0  0.0    0.0   2023  Manchester City
# 4   Crystal Palace  ...  14.1  0.0  0.0    0.0   2023  Manchester City
# 5  Nott'ham Forest  ...  14.8  0.0  0.0    0.0   2023  Manchester City
#
#   venue_code opp_code  hour  day_code
# 1          0       21    16         6
# 2          1        2    15         5
# 3          0       15    16         6
# 4          1        7    15         5
# 5          1       17    19         2
#
# [5 rows x 31 columns]

# %%
matches['target'] = (matches['result'] == 'W').astype('int')

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...   fk   pk  pkatt  season             team venue_code  \
# 1         West Ham  ...  1.0  1.0    1.0    2023  Manchester City          0
# 2      Bournemouth  ...  0.0  0.0    0.0    2023  Manchester City          1
# 3    Newcastle Utd  ...  1.0  0.0    0.0    2023  Manchester City          0
# 4   Crystal Palace  ...  0.0  0.0    0.0    2023  Manchester City          1
# 5  Nott'ham Forest  ...  0.0  0.0    0.0    2023  Manchester City          1
#
#   opp_code hour  day_code  target
# 1       21   16         6       1
# 2        2   15         5       1
# 3       15   16         6       0
# 4        7   15         5       1
# 5       17   19         2       1
#
# [5 rows x 32 columns]

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches['date'] < '2023-01-01']

# %%
test = matches[matches['date'] > '2023-01-01']

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
predictions = rf.predict(test[predictors])

# %%
acc = accuracy_score(test['target'], predictions)

# %%
acc
# Out:
# 0.5981308411214953

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=predictions))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           203  60
# 1           112  53

# %%
precision_score(test['target'], predictions)
# Out:
# 0.4690265486725664

# %% [markdown]
# Precision score is telling us that when we predict that a team will win, we are only accurate 46.9% of the time.

# %% [markdown]
# ### Creating more predictors to improve the accuracy of the model:

# %%
grouped_matches = matches.groupby('team')

# %%
group = grouped_matches.get_group('Chelsea')

# %%
def rolling_avg(group, cols, new_cols):
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f'{c}_rolling' for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_avg(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2021-09-11  17:30  Premier League   Matchweek 4  Sat  Home      W   3   0
# 6  2021-09-19  16:30  Premier League   Matchweek 5  Sun  Away      W   3   0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Home      L   0   1
# 10 2021-10-02  15:00  Premier League   Matchweek 7  Sat  Home      W   3   1
# 11 2021-10-16  17:30  Premier League   Matchweek 8  Sat  Away      W   1   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 45 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Away      W   3   1
# 46 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      D   2   2
# 47 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Away      L   0   1
# 48 2023-05-25  20:00  Premier League  Matchweek 32  Thu  Away      L   1   4
# 49 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D   1   1
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4       Aston Villa  ...         5       1    2.000000    0.333333  13.666667
# 6         Tottenham  ...         6       1    2.000000    0.333333  13.333333
# 8   Manchester City  ...         5       0    2.333333    0.333333  12.666667
# 10      Southampton  ...         5       1    2.000000    0.333333  12.333333
# 11        Brentford  ...         5       1    2.000000    0.666667  15.000000
# ..              ...  ...       ...     ...         ...         ...        ...
# 45      Bournemouth  ...         5       1    0.666667    2.333333  10.000000
# 46  Nott'ham Forest  ...         5       0    1.333333    2.000000  11.000000
# 47  Manchester City  ...         6       0    2.000000    2.000000  10.666667
# 48   Manchester Utd  ...         3       0    1.666667    1.333333  12.666667
# 49    Newcastle Utd  ...         6       0    1.000000    2.333333  13.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     4.666667    16.500000   1.333333         0.0            0.0
# 6     4.000000    17.033333   0.000000         0.0            0.0
# 8     5.333333    16.533333   0.000000         0.0            0.0
# 10    4.333333    21.666667   0.333333         0.0            0.0
# 11    6.000000    18.400000   0.333333         0.0            0.0
# ..         ...          ...        ...         ...            ...
# 45    3.333333    17.533333   0.000000         0.0            0.0
# 46    4.333333    16.866667   0.000000         0.0            0.0
# 47    5.000000    17.166667   0.333333         0.0            0.0
# 48    5.666667    16.666667   0.666667         0.0            0.0
# 49    5.666667    17.433333   0.666667         0.0            0.0
#
# [73 rows x 40 columns]

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_avg(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2021-09-11  15:00  Premier League   Matchweek 4
#                         5  2021-09-18  15:00  Premier League   Matchweek 5
#                         7  2021-09-26  16:30  Premier League   Matchweek 6
#                         8  2021-10-02  17:30  Premier League   Matchweek 7
#                         9  2021-10-18  20:00  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 39 2023-04-29  15:00  Premier League  Matchweek 34
#                         40 2023-05-06  15:00  Premier League  Matchweek 35
#                         41 2023-05-13  15:00  Premier League  Matchweek 36
#                         42 2023-05-20  15:00  Premier League  Matchweek 37
#                         43 2023-05-28  16:30  Premier League  Matchweek 38
#
#                             day venue result  gf  ga        opponent  ...  \
# team                                                                  ...
# Arsenal                 4   Sat  Home      W   1   0    Norwich City  ...
#                         5   Sat  Away      W   1   0         Burnley  ...
#                         7   Sun  Home      W   3   1       Tottenham  ...
#                         8   Sat  Away      D   0   0        Brighton  ...
#                         9   Mon  Home      D   2   2  Crystal Palace  ...
# ...                         ...   ...    ...  ..  ..             ...  ...
# Wolverhampton Wanderers 39  Sat  Away      L   0   6        Brighton  ...
#                         40  Sat  Home      W   1   0     Aston Villa  ...
#                         41  Sat  Away      L   0   2  Manchester Utd  ...
#                         42  Sat  Home      D   1   1         Everton  ...
#                         43  Sun  Away      L   0   5         Arsenal  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 4          5       1    0.000000    3.000000
#                         5          5       1    0.333333    2.333333
#                         7          6       1    0.666667    1.666667
#                         8          5       0    1.666667    0.333333
#                         9          0       0    1.333333    0.333333
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 39         5       0    1.666667    0.666667
#                         40         5       1    1.000000    2.666667
#                         41         5       0    1.000000    2.000000
#                         42         5       0    0.333333    2.666667
#                         43         6       0    0.666667    1.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 4    9.666667    2.333333    14.833333   0.333333
#                         5   12.333333    3.000000    14.133333   0.333333
#                         7   14.666667    3.000000    14.800000   0.666667
#                         8   18.333333    5.333333    18.433333   0.666667
#                         9   11.000000    4.000000    19.833333   0.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 39  11.666667    4.666667    18.700000   0.666667
#                         40  11.333333    2.333333    18.800000   0.666667
#                         41   8.000000    2.000000    17.766667   0.000000
#                         42   7.000000    1.333333    15.600000   0.000000
#                         43   8.000000    2.333333    15.333333   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 4     0.000000       0.000000
#                         5     0.000000       0.000000
#                         7     0.000000       0.000000
#                         8     0.000000       0.000000
#                         9     0.000000       0.000000
# ...                                ...            ...
# Wolverhampton Wanderers 39    0.333333       0.333333
#                         40    0.333333       0.333333
#                         41    0.333333       0.333333
#                         42    0.000000       0.000000
#                         43    0.000000       0.000000
#
# [1451 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W   1   0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W   1   0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W   3   1
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D   0   0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D   2   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 39 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0   6
# 40 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1   0
# 41 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0   2
# 42 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1   1
# 43 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   5
#
#           opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4     Norwich City  ...         5       1    0.000000    3.000000   9.666667
# 5          Burnley  ...         5       1    0.333333    2.333333  12.333333
# 7        Tottenham  ...         6       1    0.666667    1.666667  14.666667
# 8         Brighton  ...         5       0    1.666667    0.333333  18.333333
# 9   Crystal Palace  ...         0       0    1.333333    0.333333  11.000000
# ..             ...  ...       ...     ...         ...         ...        ...
# 39        Brighton  ...         5       0    1.666667    0.666667  11.666667
# 40     Aston Villa  ...         5       1    1.000000    2.666667  11.333333
# 41  Manchester Utd  ...         5       0    1.000000    2.000000   8.000000
# 42         Everton  ...         5       0    0.333333    2.666667   7.000000
# 43         Arsenal  ...         6       0    0.666667    1.000000   8.000000
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     2.333333    14.833333   0.333333    0.000000       0.000000
# 5     3.000000    14.133333   0.333333    0.000000       0.000000
# 7     3.000000    14.800000   0.666667    0.000000       0.000000
# 8     5.333333    18.433333   0.666667    0.000000       0.000000
# 9     4.000000    19.833333   0.666667    0.000000       0.000000
# ..         ...          ...        ...         ...            ...
# 39    4.666667    18.700000   0.666667    0.333333       0.333333
# 40    2.333333    18.800000   0.666667    0.333333       0.333333
# 41    2.000000    17.766667   0.000000    0.333333       0.333333
# 42    1.333333    15.600000   0.000000    0.000000       0.000000
# 43    2.333333    15.333333   0.333333    0.000000       0.000000
#
# [1451 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W   1
# 1    2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W   1
# 2    2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W   3
# 3    2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D   0
# 4    2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D   2
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 1446 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0
# 1447 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1
# 1448 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0
# 1449 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1
# 1450 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0
#
#       ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0      0    Norwich City  ...         5       1    0.000000    3.000000
# 1      0         Burnley  ...         5       1    0.333333    2.333333
# 2      1       Tottenham  ...         6       1    0.666667    1.666667
# 3      0        Brighton  ...         5       0    1.666667    0.333333
# 4      2  Crystal Palace  ...         0       0    1.333333    0.333333
# ...   ..             ...  ...       ...     ...         ...         ...
# 1446   6        Brighton  ...         5       0    1.666667    0.666667
# 1447   0     Aston Villa  ...         5       1    1.000000    2.666667
# 1448   2  Manchester Utd  ...         5       0    1.000000    2.000000
# 1449   1         Everton  ...         5       0    0.333333    2.666667
# 1450   5         Arsenal  ...         6       0    0.666667    1.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      9.666667    2.333333    14.833333   0.333333    0.000000       0.000000
# 1     12.333333    3.000000    14.133333   0.333333    0.000000       0.000000
# 2     14.666667    3.000000    14.800000   0.666667    0.000000       0.000000
# 3     18.333333    5.333333    18.433333   0.666667    0.000000       0.000000
# 4     11.000000    4.000000    19.833333   0.666667    0.000000       0.000000
# ...         ...         ...          ...        ...         ...            ...
# 1446  11.666667    4.666667    18.700000   0.666667    0.333333       0.333333
# 1447  11.333333    2.333333    18.800000   0.666667    0.333333       0.333333
# 1448   8.000000    2.000000    17.766667   0.000000    0.333333       0.333333
# 1449   7.000000    1.333333    15.600000   0.000000    0.000000       0.000000
# 1450   8.000000    2.333333    15.333333   0.333333    0.000000       0.000000
#
# [1451 rows x 40 columns]

# %% [markdown]
# ### Retraining ML Model:

# %%
def make_predictions(data, predictors):
    train = data[data['date'] < '2023-01-01']
    test = data[data['date'] > '2023-01-01']
    rf.fit(train[predictors], train['target'])
    predictions = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test['target'], prediction=predictions), index=test.index)
    precision = precision_score(test['target'], predictions)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5384615384615384

# %%
combined
# Out:
#       actual  prediction
# 51         0           1
# 52         1           0
# 53         1           1
# 54         0           1
# 55         0           1
# ...      ...         ...
# 1446       0           0
# 1447       1           0
# 1448       0           0
# 1449       0           0
# 1450       0           0
#
# [428 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[['date', 'team', 'opponent', 'result']], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  prediction       date                     team        opponent  \
# 51         0           1 2023-01-03                  Arsenal   Newcastle Utd
# 52         1           0 2023-01-15                  Arsenal       Tottenham
# 53         1           1 2023-01-22                  Arsenal  Manchester Utd
# 54         0           1 2023-02-04                  Arsenal         Everton
# 55         0           1 2023-02-11                  Arsenal       Brentford
# ...      ...         ...        ...                      ...             ...
# 1446       0           0 2023-04-29  Wolverhampton Wanderers        Brighton
# 1447       1           0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 1448       0           0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 1449       0           0 2023-05-20  Wolverhampton Wanderers         Everton
# 1450       0           0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#      result
# 51        D
# 52        W
# 53        W
# 54        L
# 55        D
# ...     ...
# 1446      L
# 1447      W
# 1448      L
# 1449      D
# 1450      L
#
# [428 rows x 6 columns]

# %% [markdown]
# Fixing inconsistencies between team names in 'team' and 'opponent' columns.

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", 
              "Manchester United": "Manchester Utd", 
              "Newcastle United": "Newcastle Utd", 
              "Tottenham Hotspur": "Tottenham", 
              "West Ham United": "West Ham", 
              "Wolverhampton Wanderers": "Wolves"} 

mapping = MissingDict(**map_values)

# %%
mapping['Arsenal']
# Out:
# 'Arsenal'

# %%
mapping['Wolverhampton Wanderers']
# Out:
# 'Wolves'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=['date','new_team'], right_on=['date', 'opponent'])

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           0             1 2023-01-03                  Arsenal
# 1           1             0 2023-01-15                  Arsenal
# 2           1             1 2023-01-22                  Arsenal
# 3           0             1 2023-02-04                  Arsenal
# 4           0             1 2023-02-11                  Arsenal
# ..        ...           ...        ...                      ...
# 402         0             0 2023-04-29  Wolverhampton Wanderers
# 403         1             0 2023-05-06  Wolverhampton Wanderers
# 404         0             0 2023-05-13  Wolverhampton Wanderers
# 405         0             0 2023-05-20  Wolverhampton Wanderers
# 406         0             0 2023-05-28  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0     Newcastle Utd        D    Arsenal         0             0
# 1         Tottenham        W    Arsenal         0             0
# 2    Manchester Utd        W    Arsenal         0             1
# 3           Everton        L    Arsenal         1             0
# 4         Brentford        D    Arsenal         0             0
# ..              ...      ...        ...       ...           ...
# 402        Brighton        L     Wolves         1             1
# 403     Aston Villa        W     Wolves         0             1
# 404  Manchester Utd        L     Wolves         1             1
# 405         Everton        D     Wolves         0             0
# 406         Arsenal        L     Wolves         1             0
#
#                        team_y opponent_y result_y      new_team_y
# 0            Newcastle United    Arsenal        D   Newcastle Utd
# 1           Tottenham Hotspur    Arsenal        L       Tottenham
# 2           Manchester United    Arsenal        L  Manchester Utd
# 3                     Everton    Arsenal        W         Everton
# 4                   Brentford    Arsenal        D       Brentford
# ..                        ...        ...      ...             ...
# 402  Brighton and Hove Albion     Wolves        W        Brighton
# 403               Aston Villa     Wolves        L     Aston Villa
# 404         Manchester United     Wolves        W  Manchester Utd
# 405                   Everton     Wolves        D         Everton
# 406                   Arsenal     Wolves        W         Arsenal
#
# [407 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    50
# 0    39
# Name: actual_x, dtype: int64

# %%
50/89
# Out:
# 0.5617977528089888
